# %%
pip install git+https://github.com/mimoralea/gym-walk#egg=gym-walk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gym-walk
#   Cloning https://github.com/mimoralea/gym-walk to c:\users\admin\appdata\local\temp\pip-install-k8e4xmn6\gym-walk_8f97cb191cd24abd9337b895d4de3145
#   Resolved https://github.com/mimoralea/gym-walk to commit c453a5da6a37b6fadb393c490261bd6b9fa5bfc5
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: gym==0.23 in c:\users\admin\appdata\roaming\python\python311\site-packages (from gym-walk) (0.23.0)
# Requirement already satisfied: pygame<3.0.0,>=2.1.2 in c:\users\admin\appdata\roaming\python\python311\site-packages (from gym-walk) (2.6.1)
# Requirement already satisfied: numpy>=1.18.0 in c:\programdata\anaconda3\lib\site-packages (from gym==0.23->gym-walk) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from gym==0.23->gym-walk) (2.2.1)
# Requirement already satisfied: gym_notices>=0.0.4 in c:\users\admin\appdata\roaming\python\python311\site-packages (from gym==0.23->gym-walk) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.
#   Running command git clone --filter=blob:none --quiet https://github.com/mimoralea/gym-walk 'C:\Users\admin\AppData\Local\Temp\pip-install-k8e4xmn6\gym-walk_8f97cb191cd24abd9337b895d4de3145'

# %%
import warnings ; warnings.filterwarnings('ignore')

import gym, gym_walk
import numpy as np

import random
import warnings

warnings.filterwarnings('ignore', category=DeprecationWarning)
np.set_printoptions(suppress=True)
random.seed(123); np.random.seed(123)
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.

# %%
def print_policy(pi, P, action_symbols=('<', 'v', '>', '^'), n_cols=4, title='Policy:'):
    print(title)
    arrs = {k:v for k,v in enumerate(action_symbols)}
    for s in range(len(P)):
        a = pi(s)
        print("| ", end="")
        if np.all([done for action in P[s].values() for _, _, _, done in action]):
            print("".rjust(9), end=" ")
        else:
            print(str(s).zfill(2), arrs[a].rjust(6), end=" ")
        if (s + 1) % n_cols == 0: print("|")

# %%
def print_state_value_function(V, P, n_cols=4, prec=3, title='State-value function:'):
    print(title)
    for s in range(len(P)):
        v = V[s]
        print("| ", end="")
        if np.all([done for action in P[s].values() for _, _, _, done in action]):
            print("".rjust(9), end=" ")
        else:
            print(str(s).zfill(2), '{}'.format(np.round(v, prec)).rjust(6), end=" ")
        if (s + 1) % n_cols == 0: print("|")

# %%
def probability_success(env, pi, goal_state, n_episodes=100, max_steps=200):
    random.seed(123); np.random.seed(123) ; env.seed(123)
    results = []
    for _ in range(n_episodes):
        state, done, steps = env.reset(), False, 0
        while not done and steps < max_steps:
            state, _, done, h = env.step(pi(state))
            steps += 1
        results.append(state == goal_state)
    return np.sum(results)/len(results)

# %%
def mean_return(env, pi, n_episodes=100, max_steps=200):
    random.seed(123); np.random.seed(123) ; env.seed(123)
    results = []
    for _ in range(n_episodes):
        state, done, steps = env.reset(), False, 0
        results.append(0.0)
        while not done and steps < max_steps:
            state, reward, done, _ = env.step(pi(state))
            results[-1] += reward
            steps += 1
    return np.mean(results)

# %% [markdown]
# # Creating the Frozen Lake environment

# %%
envdesc  = ['FSFH','HFFH','HFGF', 'FFFH']
env = gym.make('FrozenLake-v1',desc=envdesc)
init_state = env.reset()
goal_state = 10
P = env.env.P

# %%
P
# Out:
# {0: {0: [(0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 4, 0.0, True)],
#   1: [(0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 4, 0.0, True),
#    (0.3333333333333333, 1, 0.0, False)],
#   2: [(0.3333333333333333, 4, 0.0, True),
#    (0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False)],
#   3: [(0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False)]},
#  1: {0: [(0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 5, 0.0, False)],
#   1: [(0.3333333333333333, 0, 0.0, False),
#    (0.3333333333333333, 5, 0.0, False),
#    (0.3333333333333333, 2, 0.0, False)],
#   2: [(0.3333333333333333, 5, 0.0, False),
#    (0.3333333333333333, 2, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False)],
#   3: [(0.3333333333333333, 2, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 0, 0.0, False)]},
#  2: {0: [(0.3333333333333333, 2, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 6, 0.0, False)],
#   1: [(0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 6, 0.0, False),
#    (0.3333333333333333, 3, 0.0, True)],
#   2: [(0.3333333333333333, 6, 0.0, False),
#    (0.3333333333333333, 3, 0.0, True),
#    (0.3333333333333333, 2, 0.0, False)],
#   3: [(0.3333333333333333, 3, 0.0, True),
#    (0.3333333333333333, 2, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False)]},
#  3: {0: [(1.0, 3, 0, True)],
#   1: [(1.0, 3, 0, True)],
#   2: [(1.0, 3, 0, True)],
#   3: [(1.0, 3, 0, True)]},
#  4: {0: [(1.0, 4, 0, True)],
#   1: [(1.0, 4, 0, True)],
#   2: [(1.0, 4, 0, True)],
#   3: [(1.0, 4, 0, True)]},
#  5: {0: [(0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 4, 0.0, True),
#    (0.3333333333333333, 9, 0.0, False)],
#   1: [(0.3333333333333333, 4, 0.0, True),
#    (0.3333333333333333, 9, 0.0, False),
#    (0.3333333333333333, 6, 0.0, False)],
#   2: [(0.3333333333333333, 9, 0.0, False),
#    (0.3333333333333333, 6, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False)],
#   3: [(0.3333333333333333, 6, 0.0, False),
#    (0.3333333333333333, 1, 0.0, False),
#    (0.3333333333333333, 4, 0.0, True)]},
#  6: {0: [(0.3333333333333333, 2, 0.0, False),
#    (0.3333333333333333, 5, 0.0, False),
#    (0.3333333333333333, 10, 1.0, True)],
#   1: [(0.3333333333333333, 5, 0.0, False),
#    (0.3333333333333333, 10, 1.0, True),
#    (0.3333333333333333, 7, 0.0, True)],
#   2: [(0.3333333333333333, 10, 1.0, True),
#    (0.3333333333333333, 7, 0.0, True),
#    (0.3333333333333333, 2, 0.0, False)],
#   3: [(0.3333333333333333, 7, 0.0, True),
#    (0.3333333333333333, 2, 0.0, False),
#    (0.3333333333333333, 5, 0.0, False)]},
#  7: {0: [(1.0, 7, 0, True)],
#   1: [(1.0, 7, 0, True)],
#   2: [(1.0, 7, 0, True)],
#   3: [(1.0, 7, 0, True)]},
#  8: {0: [(1.0, 8, 0, True)],
#   1: [(1.0, 8, 0, True)],
#   2: [(1.0, 8, 0, True)],
#   3: [(1.0, 8, 0, True)]},
#  9: {0: [(0.3333333333333333, 5, 0.0, False),
#    (0.3333333333333333, 8, 0.0, True),
#    (0.3333333333333333, 13, 0.0, False)],
#   1: [(0.3333333333333333, 8, 0.0, True),
#    (0.3333333333333333, 13, 0.0, False),
#    (0.3333333333333333, 10, 1.0, True)],
#   2: [(0.3333333333333333, 13, 0.0, False),
#    (0.3333333333333333, 10, 1.0, True),
#    (0.3333333333333333, 5, 0.0, False)],
#   3: [(0.3333333333333333, 10, 1.0, True),
#    (0.3333333333333333, 5, 0.0, False),
#    (0.3333333333333333, 8, 0.0, True)]},
#  10: {0: [(1.0, 10, 0, True)],
#   1: [(1.0, 10, 0, True)],
#   2: [(1.0, 10, 0, True)],
#   3: [(1.0, 10, 0, True)]},
#  11: {0: [(0.3333333333333333, 7, 0.0, True),
#    (0.3333333333333333, 10, 1.0, True),
#    (0.3333333333333333, 15, 0.0, True)],
#   1: [(0.3333333333333333, 10, 1.0, True),
#    (0.3333333333333333, 15, 0.0, True),
#    (0.3333333333333333, 11, 0.0, False)],
#   2: [(0.3333333333333333, 15, 0.0, True),
#    (0.3333333333333333, 11, 0.0, False),
#    (0.3333333333333333, 7, 0.0, True)],
#   3: [(0.3333333333333333, 11, 0.0, False),
#    (0.3333333333333333, 7, 0.0, True),
#    (0.3333333333333333, 10, 1.0, True)]},
#  12: {0: [(0.3333333333333333, 8, 0.0, True),
#    (0.3333333333333333, 12, 0.0, False),
#    (0.3333333333333333, 12, 0.0, False)],
#   1: [(0.3333333333333333, 12, 0.0, False),
#    (0.3333333333333333, 12, 0.0, False),
#    (0.3333333333333333, 13, 0.0, False)],
#   2: [(0.3333333333333333, 12, 0.0, False),
#    (0.3333333333333333, 13, 0.0, False),
#    (0.3333333333333333, 8, 0.0, True)],
#   3: [(0.3333333333333333, 13, 0.0, False),
#    (0.3333333333333333, 8, 0.0, True),
#    (0.3333333333333333, 12, 0.0, False)]},
#  13: {0: [(0.3333333333333333, 9, 0.0, False),
#    (0.3333333333333333, 12, 0.0, False),
#    (0.3333333333333333, 13, 0.0, False)],
#   1: [(0.3333333333333333, 12, 0.0, False),
#    (0.3333333333333333, 13, 0.0, False),
#    (0.3333333333333333, 14, 0.0, False)],
#   2: [(0.3333333333333333, 13, 0.0, False),
#    (0.3333333333333333, 14, 0.0, False),
#    (0.3333333333333333, 9, 0.0, False)],
#   3: [(0.3333333333333333, 14, 0.0, False),
#    (0.3333333333333333, 9, 0.0, False),
#    (0.3333333333333333, 12, 0.0, False)]},
#  14: {0: [(0.3333333333333333, 10, 1.0, True),
#    (0.3333333333333333, 13, 0.0, False),
#    (0.3333333333333333, 14, 0.0, False)],
#   1: [(0.3333333333333333, 13, 0.0, False),
#    (0.3333333333333333, 14, 0.0, False),
#    (0.3333333333333333, 15, 0.0, True)],
#   2: [(0.3333333333333333, 14, 0.0, False),
#    (0.3333333333333333, 15, 0.0, True),
#    (0.3333333333333333, 10, 1.0, True)],
#   3: [(0.3333333333333333, 15, 0.0, True),
#    (0.3333333333333333, 10, 1.0, True),
#    (0.3333333333333333, 13, 0.0, False)]},
#  15: {0: [(1.0, 15, 0, True)],
#   1: [(1.0, 15, 0, True)],
#   2: [(1.0, 15, 0, True)],
#   3: [(1.0, 15, 0, True)]}}

# %% [markdown]
# # Value Iteration Algorithm

# %%
def value_iteration(P, gamma=1.0, theta=1e-10):
    V = np.zeros(len(P), dtype=np.float64)
    while True:
      Q=np.zeros((len(P),len(P[0])),dtype=np.float64)
      for s in range(len(P)):
        for a in range(len(P[s])):
          for prob,next_state,reward,done in P[s][a]:
            Q[s][a]+=prob*(reward+gamma*V[next_state]*(not done))
      if np.max(np.abs(V-np.max(Q,axis=1)))<theta:
        break
      V=np.max(Q,axis=1)
    pi=lambda s:{s:a for s,a in enumerate(np.argmax(Q,axis=1))}[s]
    return V, pi

# %%
# Finding the optimal policy
V_best_v, pi_best_v = value_iteration(P, gamma=0.99)

# %%
# Printing the policy
print("Name:NANDAKESORE J  Register Number:212223240103")
print('Optimal policy and state-value function (VI):')
print_policy(pi_best_v, P)
# Out:
# Name:NANDAKESORE J  Register Number:212223240103
# Optimal policy and state-value function (VI):
# Policy:
# | 00      ^ | 01      > | 02      < |           |
# |           | 05      > | 06      < |           |
# |           | 09      > |           | 11      v |
# | 12      v | 13      > | 14      < |           |

# %%
# printing the success rate and the mean return
print('Reaches goal {:.2f}%. Obtains an average undiscounted return of {:.4f}.'.format(
    probability_success(env, pi_best_v, goal_state=goal_state)*100,
    mean_return(env, pi_best_v)))
# Out:
# Reaches goal 100.00%. Obtains an average undiscounted return of 1.0000.

# %%
# printing the state value function
print_state_value_function(V_best_v, P, prec=4)
# Out:
# State-value function:
# | 00 0.8657 | 01 0.8919 | 02 0.8978 |           |
# |           | 05  0.913 | 06 0.9309 |           |
# |           | 09  0.944 |           | 11 0.4975 |
# | 12 0.9098 | 13 0.9374 | 14 0.9592 |           |
